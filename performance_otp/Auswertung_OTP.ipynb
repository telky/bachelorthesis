# %%
#import libs
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from pandas.tseries.offsets import *

#higher format
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
#read csv
data = pd.read_excel('/Users/ths2be/Desktop/BA/OTP/otp_auswertung.xlsx')
print(data)
# Out:
#           timeStamp  elapsed             label  responseCode responseMessage  \
# 0     1556011164912     4488   Request_Route_1           200              OK
# 1     1556011164203     5197   Request_Route_1           200              OK
# 2     1556011164642     4758   Request_Route_1           200              OK
# 3     1556011165176     4224   Request_Route_1           200              OK
# 4     1556011164376     5160   Request_Route_1           200              OK
# 5     1556011165445     4241   Request_Route_1           200              OK
# 6     1556011165711     4291   Request_Route_1           200              OK
# 7     1556011166244     3873   Request_Route_1           200              OK
# 8     1556011165978     4180   Request_Route_1           200              OK
# 9     1556011166512     3671   Request_Route_1           200              OK
# 10    1556011167050     4717   Request_Route_1           200              OK
# ...

# %%
## Latenz Route 1 ##
# y = data.loc[data['label'] == 'Request_Route_1'].reset_index()
# x = y['Latency']

# # print(x)

# #plot latency
# latencyPlot = x.plot(kind='line', linestyle='solid', title='Latenzen', legend=True, grid=True, figsize=(30,10))
# latencyPlot.set(xlabel='Latenzen', ylabel='Sekunden')

## latency all routes ##
route1 = data.loc[data['label'] == 'Request_Route_1'].reset_index()
route2 = data.loc[data['label'] == 'Request_Route_2'].reset_index()
route3 = data.loc[data['label'] == 'Request_Route_3'].reset_index()
route4 = data.loc[data['label'] == 'Request_Route_4'].reset_index()
route5 = data.loc[data['label'] == 'Request_Route_5'].reset_index()
route6 = data.loc[data['label'] == 'Request_Route_6'].reset_index()
route7 = data.loc[data['label'] == 'Request_Route_7'].reset_index()
route8 = data.loc[data['label'] == 'Request_Route_8'].reset_index()
route9 = data.loc[data['label'] == 'Request_Route_9'].reset_index()
route10 = data.loc[data['label'] == 'Request_Route_10'].reset_index()
route11 = data.loc[data['label'] == 'Request_Route_11'].reset_index()
route12 = data.loc[data['label'] == 'Request_Route_12'].reset_index()
route13 = data.loc[data['label'] == 'Request_Route_13'].reset_index()
route14 = data.loc[data['label'] == 'Request_Route_14'].reset_index()
route15 = data.loc[data['label'] == 'Request_Route_15'].reset_index()
route1 = route1['Latency'].to_frame().rename(columns={'Latency': 'Route1'})
route2 = route2['Latency'].to_frame().rename(columns={'Latency': 'Route2'})
route3 = route3['Latency'].to_frame().rename(columns={'Latency': 'Route3'})
route4 = route4['Latency'].to_frame().rename(columns={'Latency': 'Route4'})
route5 = route5['Latency'].to_frame().rename(columns={'Latency': 'Route5'})
route6 = route6['Latency'].to_frame().rename(columns={'Latency': 'Route6'})
route7 = route7['Latency'].to_frame().rename(columns={'Latency': 'Route7'})
route8 = route8['Latency'].to_frame().rename(columns={'Latency': 'Route8'})
route9 = route9['Latency'].to_frame().rename(columns={'Latency': 'Route9'})
route10 = route10['Latency'].to_frame().rename(columns={'Latency': 'Route10'})
route11 = route11['Latency'].to_frame().rename(columns={'Latency': 'Route11'})
route12 = route12['Latency'].to_frame().rename(columns={'Latency': 'Route12'})
route13 = route13['Latency'].to_frame().rename(columns={'Latency': 'Route13'})
route14 = route14['Latency'].to_frame().rename(columns={'Latency': 'Route14'})
route15 = route15['Latency'].to_frame().rename(columns={'Latency': 'Route15'})

result = pd.concat([route1, route2, route3, route4, route5, route6, route7, route8, route9, route10, route11, route12, route13, route14, route15], axis=1)

result.boxplot(figsize=(70,20),fontsize=15, rot=45)

# %%
## bytes all routes ##
route1 = data.loc[data['label'] == 'Request_Route_1'].reset_index()
route2 = data.loc[data['label'] == 'Request_Route_2'].reset_index()
route3 = data.loc[data['label'] == 'Request_Route_3'].reset_index()
route4 = data.loc[data['label'] == 'Request_Route_4'].reset_index()
route5 = data.loc[data['label'] == 'Request_Route_5'].reset_index()
route6 = data.loc[data['label'] == 'Request_Route_6'].reset_index()
route7 = data.loc[data['label'] == 'Request_Route_7'].reset_index()
route8 = data.loc[data['label'] == 'Request_Route_8'].reset_index()
route9 = data.loc[data['label'] == 'Request_Route_9'].reset_index()
route10 = data.loc[data['label'] == 'Request_Route_10'].reset_index()
route11 = data.loc[data['label'] == 'Request_Route_11'].reset_index()
route12 = data.loc[data['label'] == 'Request_Route_12'].reset_index()
route13 = data.loc[data['label'] == 'Request_Route_13'].reset_index()
route14 = data.loc[data['label'] == 'Request_Route_14'].reset_index()
route15 = data.loc[data['label'] == 'Request_Route_15'].reset_index()
route1 = route1['bytes'].to_frame().rename(columns={'bytes': 'Route1'})
route2 = route2['bytes'].to_frame().rename(columns={'bytes': 'Route2'})
route3 = route3['bytes'].to_frame().rename(columns={'bytes': 'Route3'})
route4 = route4['bytes'].to_frame().rename(columns={'bytes': 'Route4'})
route5 = route5['bytes'].to_frame().rename(columns={'bytes': 'Route5'})
route6 = route6['bytes'].to_frame().rename(columns={'bytes': 'Route6'})
route7 = route7['bytes'].to_frame().rename(columns={'bytes': 'Route7'})
route8 = route8['bytes'].to_frame().rename(columns={'bytes': 'Route8'})
route9 = route9['bytes'].to_frame().rename(columns={'bytes': 'Route9'})
route10 = route10['bytes'].to_frame().rename(columns={'bytes': 'Route10'})
route11 = route11['bytes'].to_frame().rename(columns={'bytes': 'Route11'})
route12 = route12['bytes'].to_frame().rename(columns={'bytes': 'Route12'})
route13 = route13['bytes'].to_frame().rename(columns={'bytes': 'Route13'})
route14 = route14['bytes'].to_frame().rename(columns={'bytes': 'Route14'})
route15 = route15['bytes'].to_frame().rename(columns={'bytes': 'Route15'})

result = pd.concat([route1, route2, route3, route4, route5, route6, route7, route8, route9, route10, route11, route12, route13, route14, route15], axis=1)

result.boxplot(figsize=(50,20))
